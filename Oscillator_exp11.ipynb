# %% [markdown]
# <a href="https://colab.research.google.com/github/TokushigeJunya/ForcedHNN/blob/main/Oscillator_exp11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import autograd
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate
solve_ivp = scipy.integrate.solve_ivp
from scipy.optimize import fsolve

def GL2(F,t,y,h):
    def func(z):
        F1 = np.zeros(y.size)
        F2 = np.zeros(y.size)
        F3 = np.zeros(y.size*2)
        F1 = F(t+(3-(3**0.5))*h/6,y+h*(z[:y.size]/4+(3-2*(3**0.5))*z[y.size:]/12))
        F2 = F(t+(3+(3**0.5))*h/6,y+h*((3+2*(3**0.5))*z[:y.size]/12+z[y.size:]/4))
        F3 = np.concatenate([F1,F2])
        return z-F3
    k = fsolve(func,np.concatenate([F(t,y),F(t,y)]))
    return h*(k[:y.size]+k[y.size:])/2

def solve_ivp_symp(fun, t_span, y0, t_eval):
    h = t_eval[1] - t_eval[0]
    t = t_span[0]
    y = y0
    ts = []
    ys = []
    ys.append(y)
    i = 1
    while i < t_eval.size:
        y = y + GL2(fun,t,y,h)
        t = t + h
        ts.append(t)
        ys.append(y)
        i += 1
    ys = np.stack(ys).T
    sol ={'t' : ts, 'y' : ys}
    return(sol)

def hamiltonian_fn(coords):   #coords = [q, p]
    q, p = np.split(coords,2)
    one = np.ones_like(q)
    H = 0.5*(q**2) + 0.5*(p**2)   #hamiltonian
    return H

def dynamics_fn(t,coords):
    q = torch.tensor([coords[0].item()], requires_grad=True, dtype=torch.float32)
    p = torch.tensor([coords[1].item()], requires_grad=True, dtype=torch.float32)
    one = torch.ones_like(q, requires_grad=True, dtype=torch.float32)
    H = 0.5*(q**2) + 0.5*(p**2)   #hamiltonian
    dHdq = torch.autograd.grad(H, q, create_graph=True)[0].detach().numpy().reshape(-1)
    dHdp = torch.autograd.grad(H, p, create_graph=True)[0].detach().numpy().reshape(-1)
    S = np.concatenate([dHdp, -dHdq], axis=-1)
    return S

def dynamics_fn_ext(t, coords):
    q = torch.tensor([coords[0].item()], requires_grad=True, dtype=torch.float32)
    p = torch.tensor([coords[1].item()], requires_grad=True, dtype=torch.float32)
    one = torch.ones_like(q, requires_grad=True, dtype=torch.float32)
    H = 0.5*(q**2) + 0.5*(p**2)   #hamiltonian
    dHdq = torch.autograd.grad(H, q, create_graph=True)[0].detach().numpy().reshape(-1)
    dHdp = torch.autograd.grad(H, p, create_graph=True)[0].detach().numpy().reshape(-1)
    S = np.concatenate([dHdp, -dHdq + np.array(0.25*(1-coords[0]*coords[0])*coords[1])], axis=-1)
    return S

def ext_f(coords):
    q, p = np.split(coords,2)
    f = 0.25*(1-q*q)*p
    return f

def get_trajectory(t_span=[0,3], timescale=10, radius=None, y0=None, noise_std=0.05, ext=False):   #ノイズの大きさを変えたいときは、noise_stdを変える
    t_eval = np.linspace(t_span[0], t_span[1], int(timescale*(t_span[1]-t_span[0])))

    # get initial state
    if y0 is None:
        y0 = np.random.rand(2)*2 - 1
    if radius is None:
        radius = np.random.rand()*0.9 + 0.1 # sample a range of radii
    y0 = y0 / np.sqrt((y0**2).sum()) * radius # set the appropriate radius

    if ext:
        spring_ivp = solve_ivp(fun=dynamics_fn_ext, t_span=t_span, y0=y0, t_eval=t_eval, rtol=1e-10)
    else:
        spring_ivp = solve_ivp_symp(fun=dynamics_fn, t_span=t_span, y0=y0, t_eval=t_eval)

    q, p = spring_ivp['y'][0], spring_ivp['y'][1]

    if ext:
        dydt = [dynamics_fn_ext(None, y) for y in spring_ivp['y'].T]
    else:
        dydt = [dynamics_fn(None, y) for y in spring_ivp['y'].T]

    dydt = np.stack(dydt).T
    dqdt, dpdt = np.split(dydt,2)

    # add noise
    q += np.random.randn(*q.shape)*noise_std
    p += np.random.randn(*p.shape)*noise_std
    return q, p, dqdt, dpdt, t_eval

def get_dataset(samples=50, test_split=0.5, ext=False, noise_std=0.05):   #ノイズの大きさを変えたいときは、noise_stdを変える
    data = {'meta': locals()}

    # randomly sample inputs
    np.random.seed(0)
    torch.manual_seed(0)
    xs, dxs = [], []
    for s in range(samples):
        x, y, dx, dy, t = get_trajectory(ext=ext,noise_std=noise_std)
        xs.append( np.stack([x, y]).T )
        dxs.append( np.stack([dx, dy]).T )

    data['x'] = np.concatenate(xs)
    data['dx'] = np.concatenate(dxs).squeeze()

    # make a train/test split
    split_ix = int(len(data['x']) * test_split)
    split_data = {}
    for k in ['x', 'dx']:
        split_data[k], split_data['test_' + k] = data[k][:split_ix], data[k][split_ix:]
    data = split_data
    return data

# %%
class quadpoly(torch.nn.Module): #MLPを多項式に特化したquadpolyに変える

    def __init__(self):
        super(quadpoly, self).__init__()
        w = torch.tensor([[1.1],[-1.2],[0.5],[1.1],[1.3],[2.2],[0.6],[1.3],[3.0],[0.8]], requires_grad=True, dtype=torch.float32)
        self.w = torch.nn.Parameter(w)

    def forward(self, x):
        q,p = torch.hsplit(x,2)
        one = torch.ones_like(q)
        M = torch.concatenate([q*q*q,p*p*p,q*q*p,q*p*p,q*q,p*p,q*p,q,p,one],dim=1)
        f = torch.mm(M,self.w)
        return f

class MLP(torch.nn.Module):

    def __init__(self, input_dim, hidden_dim, output_dim):
        super(MLP, self).__init__()
        self.linear1 = torch.nn.Linear(input_dim, hidden_dim)
        self.linear2 = torch.nn.Linear(hidden_dim, hidden_dim)
        self.linear3 = torch.nn.Linear(hidden_dim, output_dim, bias=None)

        for l in [self.linear1, self.linear2, self.linear3]:
            torch.nn.init.orthogonal_(l.weight) # use a principled initialization

        self.nonlinearity = torch.tanh

    def forward(self, x):
        h = self.nonlinearity( self.linear1(x) )
        h = self.nonlinearity( self.linear2(h) )
        return self.linear3(h)

class HNN(torch.nn.Module):
    '''Learn arbitrary vector fields that are sums of conservative and solenoidal fields'''
    def __init__(self, input_dim, differentiable_model, baseline=False):
        super(HNN, self).__init__()
        self.baseline = baseline
        self.differentiable_model = differentiable_model
        self.M = self.permutation_tensor(input_dim)

    def forward(self, x):
        # traditional forward pass
        return self.differentiable_model(x)

    def derivative(self, x, t=None):
        '''NEURAL ODE-STLE VECTOR FIELD'''
        if self.baseline:
            return self.differentiable_model(x)

        '''NEURAL HAMILTONIAN-STLE VECTOR FIELD'''
        F = self.forward(x) # traditional forward pass
        dF = torch.autograd.grad(F.sum(), x, create_graph=True)[0]

        return dF @ self.M.t()

    def permutation_tensor(self,n):
        M = torch.eye(n)
        M = torch.cat([M[n//2:], -M[:n//2]])
        return M

class Forced_HNN(torch.nn.Module):
    '''Learn arbitrary vector fields that are sums of conservative and solenoidal fields'''
    def __init__(self, input_dim, ext_model, hnn_model, baseline=False):
        super(Forced_HNN, self).__init__()
        self.baseline = baseline
        self.ext_model = ext_model
        self.hnn_model = hnn_model
        self.M = self.permutation_tensor(input_dim)

    def forward(self, x):
        # traditional forward pass
       return self.ext_model(x)

    def derivative(self, x, t=None):

        '''NEURAL HAMILTONIAN-STLE VECTOR FIELD'''
        F = self.hnn_model(x) # traditional forward pass
        dF = torch.autograd.grad(F.sum(), x, create_graph=True)[0]
        dydt = dF @ self.M.t()
        a, b = torch.hsplit(dydt,2)
        b = b + self.ext_model(x)

        return torch.cat((a, b), dim=1)

    def permutation_tensor(self,n):
        M = torch.eye(n)
        M = torch.cat([M[n//2:], -M[:n//2]])
        return M

# %%
print_every = 200

def L2_loss(u, v):
    return (u-v).pow(2).mean()

def train(baseline, total_steps, data, ext=False, hnn_model=None):

    # set random seed
    torch.manual_seed(0)
    np.random.seed(0)

    # init model and optimizer
    if ext:
        print("Training baseline model:" if baseline else "Training  Forced HNN model:")
        ext_model = quadpoly()   #MLPをquadpolyに変えた
        model = Forced_HNN(input_dim=2, ext_model=ext_model, hnn_model=hnn_model)
        optim = torch.optim.Adam(model.ext_model.parameters(), weight_decay=1e-4)

    else:
        print("Training baseline model:" if baseline else "Training HNN model:")
        if baseline:
            differentiable_model = MLP(input_dim=2, hidden_dim=200, output_dim=2)
            model = HNN(input_dim=2, differentiable_model=differentiable_model, baseline=True)
        else:
            differentiable_model = quadpoly()   #MLPをquadpolyに変えた
            model = HNN(input_dim=2, differentiable_model=differentiable_model)
        optim = torch.optim.Adam(model.parameters(), weight_decay=1e-4)

     # arrange data
    x = torch.tensor( data['x'], requires_grad=True, dtype=torch.float32)
    test_x = torch.tensor( data['test_x'], requires_grad=True, dtype=torch.float32)
    dxdt = torch.tensor(data['dx'])
    test_dxdt = torch.tensor(data['test_dx'])

    # vanilla train loop
    stats = {'train_loss': [], 'test_loss': []}
    for step in range(total_steps+1):

        # train step
        if baseline:
            dxdt_hat = model(x)
            loss = L2_loss(dxdt, dxdt_hat)
            loss.backward() ; optim.step() ; optim.zero_grad()

        else:
            dxdt_hat = model.derivative(x)
            loss = L2_loss(dxdt, dxdt_hat)
            loss.backward() ; optim.step() ; optim.zero_grad()

        # run test data
        if baseline:
            test_dxdt_hat = model(test_x)
            test_loss = L2_loss(test_dxdt, test_dxdt_hat)

        else:
            test_dxdt_hat = model.derivative(test_x)
            test_loss = L2_loss(test_dxdt, test_dxdt_hat)

        # logging
        stats['train_loss'].append(loss.item())
        stats['test_loss'].append(test_loss.item())
        if step % print_every == 0:
            print("step {}, train_loss {:.4e}, test_loss {:.4e}".format(step, loss.item(), test_loss.item()))

    if baseline:
        train_dxdt_hat = model(x)

    else:
        train_dxdt_hat = model.derivative(x)

    train_dist = (dxdt - train_dxdt_hat).pow(2)

    if baseline:
        test_dxdt_hat = model(test_x)

    else:
        test_dxdt_hat = model.derivative(test_x)

    test_dist = (test_dxdt - test_dxdt_hat).pow(2)

    print('Final train loss {:.4e} +/- {:.4e}\nFinal test loss {:.4e} +/- {:.4e}'
      .format(train_dist.mean().item(), train_dist.std().item()/np.sqrt(train_dist.shape[0]),
              test_dist.mean().item(), test_dist.std().item()/np.sqrt(test_dist.shape[0])))

    return model, stats

# %%
t_span = [0,100]
y0 = np.asarray([1, 0])
t_eval=np.linspace(t_span[0], t_span[1], 2000)

def integrate(t_span=[0,100], y0=np.asarray([1, 0]), t_eval=np.linspace(t_span[0], t_span[1], 2000), ext=False, rtol=1e-10):

    if ext:
        return solve_ivp(fun=dynamics_fn_ext, t_span=t_span, y0=y0, t_eval=np.linspace(t_span[0], t_span[1], 2000), rtol=rtol)
    else:
        return solve_ivp_symp(fun=dynamics_fn, t_span=t_span, y0=y0, t_eval=np.linspace(t_span[0], t_span[1], 2000))

def integrate_model(model, t_span=[0,100], y0=np.asarray([1, 0]), t_eval=np.linspace(t_span[0], t_span[1], 2000),  baseline=True, rtol=1e-10, ext=False):

    if baseline:
        def fun(t, np_y):
            y = torch.tensor(np_y, requires_grad=True, dtype=torch.float32).view(1,2)
            dy = model(y).detach().numpy().reshape(-1)
            return dy
        if ext:
            return solve_ivp(fun=fun, t_span=t_span, y0=y0, t_eval=t_eval, rtol=rtol)
        else:
            return solve_ivp_symp(fun=fun, t_span=t_span, y0=y0, t_eval=t_eval)

    else:
        def fun(t, np_y):
            y = torch.tensor(np_y, requires_grad=True, dtype=torch.float32).view(1,2)
            dy = model.derivative(y).detach().numpy().reshape(-1)
            return dy
        if ext:
            return solve_ivp(fun=fun, t_span=t_span, y0=y0, t_eval=t_eval, rtol=rtol)
        else:
            return solve_ivp_symp(fun=fun, t_span=t_span, y0=y0, t_eval=t_eval)

# %%
data = get_dataset()
data_ext = get_dataset(ext=True)

# %%
model_bnn, stats_bnn = train(baseline=True, data=data, total_steps=9000)
model_hnn, stats_hnn = train(baseline=False, data=data, total_steps=9000)
# Out:
# Training baseline model:
# step 0, train_loss 2.5026e-01, test_loss 3.7558e-01
# step 200, train_loss 2.3850e-03, test_loss 2.3521e-03
# step 400, train_loss 2.3841e-03, test_loss 2.3526e-03
# step 600, train_loss 2.3835e-03, test_loss 2.3527e-03
# step 800, train_loss 2.3832e-03, test_loss 2.3529e-03
# step 1000, train_loss 7.2060e-03, test_loss 6.8363e-03
# step 1200, train_loss 2.3824e-03, test_loss 2.3538e-03
# step 1400, train_loss 2.4827e-03, test_loss 2.3720e-03
# step 1600, train_loss 2.3822e-03, test_loss 2.3540e-03
# step 1800, train_loss 2.4978e-03, test_loss 2.8043e-03
# step 2000, train_loss 2.3820e-03, test_loss 2.3540e-03
# step 2200, train_loss 2.3820e-03, test_loss 2.3542e-03
# step 2400, train_loss 2.3835e-03, test_loss 2.3540e-03
# step 2600, train_loss 2.4244e-03, test_loss 2.4275e-03
# step 2800, train_loss 2.3820e-03, test_loss 2.3542e-03
# step 3000, train_loss 2.3819e-03, test_loss 2.3541e-03
# step 3200, train_loss 2.3819e-03, test_loss 2.3539e-03
# step 3400, train_loss 2.3819e-03, test_loss 2.3540e-03
# step 3600, train_loss 2.3819e-03, test_loss 2.3542e-03
# step 3800, train_loss 2.3818e-03, test_loss 2.3539e-03
# step 4000, train_loss 2.3819e-03, test_loss 2.3539e-03
# step 4200, train_loss 2.3818e-03, test_loss 2.3537e-03
# step 4400, train_loss 2.3823e-03, test_loss 2.3549e-03
# step 6200, train_loss 2.3812e-03, test_loss 2.3525e-03
# step 6400, train_loss 2.3811e-03, test_loss 2.3522e-03
# step 6600, train_loss 2.3809e-03, test_loss 2.3519e-03
# step 6800, train_loss 2.3807e-03, test_loss 2.3515e-03
# step 7000, train_loss 2.3804e-03, test_loss 2.3511e-03
# step 7200, train_loss 2.3800e-03, test_loss 2.3507e-03
# step 7400, train_loss 2.3796e-03, test_loss 2.3502e-03
# step 7600, train_loss 2.3791e-03, test_loss 2.3498e-03
# step 7800, train_loss 2.3787e-03, test_loss 2.3494e-03
# step 8000, train_loss 2.3782e-03, test_loss 2.3492e-03
# step 8200, train_loss 2.3779e-03, test_loss 2.3491e-03
# step 8400, train_loss 2.3776e-03, test_loss 2.3490e-03
# step 8600, train_loss 2.3775e-03, test_loss 2.3488e-03
# step 8800, train_loss 2.3773e-03, test_loss 2.3489e-03
# step 9000, train_loss 2.3773e-03, test_loss 2.3490e-03
# Final train loss 2.3777e-03 +/- 1.2143e-04
# Final test loss 2.3490e-03 +/- 1.1937e-04
# Training HNN model:
# step 0, train_loss 7.1827e+00, test_loss 8.1823e+00
# step 200, train_loss 5.5038e+00, test_loss 5.9678e+00
# step 400, train_loss 4.2115e+00, test_loss 4.3950e+00
# step 600, train_loss 3.2090e+00, test_loss 3.2675e+00
# step 800, train_loss 2.4372e+00, test_loss 2.4375e+00
# step 1000, train_loss 1.8511e+00, test_loss 1.8237e+00
# step 1200, train_loss 1.4114e+00, test_loss 1.3740e+00
# step 1400, train_loss 1.0839e+00, test_loss 1.0474e+00
# step 1600, train_loss 8.4056e-01, test_loss 8.1090e-01
# step 1800, train_loss 6.5890e-01, test_loss 6.3850e-01
# step 2000, train_loss 5.2174e-01, test_loss 5.1087e-01
# step 2200, train_loss 4.1646e-01, test_loss 4.1402e-01
# step 2400, train_loss 3.3401e-01, test_loss 3.3828e-01
# step 2600, train_loss 2.6815e-01, test_loss 2.7711e-01
# step 2800, train_loss 2.1460e-01, test_loss 2.2628e-01
# step 3000, train_loss 1.7049e-01, test_loss 1.8318e-01
# step 3200, train_loss 1.3394e-01, test_loss 1.4628e-01
# step 3400, train_loss 1.0369e-01, test_loss 1.1474e-01
# step 3600, train_loss 7.8841e-02, test_loss 8.8095e-02
# step 3800, train_loss 5.8740e-02, test_loss 6.6039e-02
# step 4000, train_loss 4.2807e-02, test_loss 4.8250e-02
# step 4200, train_loss 3.0495e-02, test_loss 3.4338e-02
# step 4400, train_loss 2.1263e-02, test_loss 2.3829e-02
# step 4600, train_loss 1.4577e-02, test_loss 1.6190e-02
# step 4800, train_loss 9.9216e-03, test_loss 1.0868e-02
# step 5000, train_loss 6.8215e-03, test_loss 7.3297e-03
# step 5200, train_loss 4.8583e-03, test_loss 5.0980e-03
# step 5400, train_loss 3.6831e-03, test_loss 3.7711e-03
# step 5600, train_loss 3.0229e-03, test_loss 3.0331e-03
# step 5800, train_loss 2.6772e-03, test_loss 2.6530e-03
# step 6000, train_loss 2.5100e-03, test_loss 2.4739e-03
# step 6200, train_loss 2.4359e-03, test_loss 2.3981e-03
# step 6400, train_loss 2.4061e-03, test_loss 2.3702e-03
# step 6600, train_loss 2.3954e-03, test_loss 2.3618e-03
# step 6800, train_loss 2.3919e-03, test_loss 2.3602e-03
# step 7000, train_loss 2.3910e-03, test_loss 2.3604e-03
# step 7200, train_loss 2.3907e-03, test_loss 2.3608e-03
# step 7400, train_loss 2.3907e-03, test_loss 2.3611e-03
# step 7600, train_loss 2.3907e-03, test_loss 2.3612e-03
# step 7800, train_loss 2.3907e-03, test_loss 2.3613e-03
# step 8000, train_loss 2.3907e-03, test_loss 2.3613e-03
# step 8200, train_loss 2.3907e-03, test_loss 2.3613e-03
# step 8400, train_loss 2.3907e-03, test_loss 2.3613e-03
# step 8600, train_loss 2.3907e-03, test_loss 2.3613e-03
# step 8800, train_loss 2.3907e-03, test_loss 2.3613e-03
# step 9000, train_loss 2.3907e-03, test_loss 2.3613e-03
# Final train loss 2.3907e-03 +/- 1.2201e-04
# Final test loss 2.3613e-03 +/- 1.2058e-04

# %%
print(model_hnn.state_dict())
# Out:
# OrderedDict([('differentiable_model.w', tensor([[ 7.6493e-04],
#         [ 2.8378e-03],
#         [-1.4792e-03],
#         [ 8.5846e-04],
#         [ 4.9171e-01],
#         [ 4.9532e-01],
#         [-7.6967e-04],
#         [ 3.5146e-04],
#         [-8.4620e-04],
#         [-1.6022e-39]]))])

# %%
integrate_true = integrate()
integrate_model_bnn = integrate_model(model_bnn)
integrate_model_hnn = integrate_model(model_hnn, baseline=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_minpack_py.py:177: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %%
DPI = 300
LINE_SEGMENTS = 10
ARROW_SCALE = 30
ARROW_WIDTH = 6e-3
LINE_WIDTH = 2

# %%
fig = plt.figure(figsize=(12.3, 3.1), facecolor='white', dpi=DPI)

#plot ground truth
fig.add_subplot(1, 3, 1, frameon=True)

for i, l in enumerate(np.split(integrate_true['y'].T, LINE_SEGMENTS)):
    color = (float(i)/LINE_SEGMENTS, 0, 1-float(i)/LINE_SEGMENTS)
    plt.plot(l[:,0],l[:,1], color=color, linewidth=LINE_WIDTH)

plt.xlabel("$q$", fontsize=14)
plt.ylabel("$p$", rotation=0, fontsize=14)
plt.title("Groundtruth", pad=10)

# plot baseline
fig.add_subplot(1, 3, 2, frameon=True)

for i, l in enumerate(np.split(integrate_model_bnn['y'].T, LINE_SEGMENTS)):
    color = (float(i)/LINE_SEGMENTS, 0, 1-float(i)/LINE_SEGMENTS)
    plt.plot(l[:,0],l[:,1],color=color, linewidth=LINE_WIDTH)

plt.xlabel("$q$", fontsize=14)
plt.ylabel("$p$", rotation=0, fontsize=14)
plt.title("Baseline NN", pad=10)

# plot HNN
fig.add_subplot(1, 3, 3, frameon=True)

for i, l in enumerate(np.split(integrate_model_hnn['y'].T, LINE_SEGMENTS)):
    color = (float(i)/LINE_SEGMENTS, 0, 1-float(i)/LINE_SEGMENTS)
    plt.plot(l[:,0],l[:,1],color=color, linewidth=LINE_WIDTH)

plt.xlabel("$q$", fontsize=14)
plt.ylabel("$p$", rotation=0, fontsize=14)
plt.title("HNN", pad=10)
# Out:
# Text(0.5, 1.0, 'HNN')

# %%
fig = plt.figure(figsize=(12.3, 3.1), facecolor='white', dpi=DPI)
tpad =7
noise_std = 0.05   #ノイズの設定を忘れないこと
t_span = [0,100]
y0 = np.asarray([1, 0])
t_eval=np.linspace(t_span[0], t_span[1], 2000)

# integrate along ground truth vector field
true_path = solve_ivp(fun=dynamics_fn, t_span=t_span, y0=y0, t_eval=t_eval, rtol=1e-12)
true_y = true_path['y'].T

# ノイズの影響を補正するために時間を再スケールする必要があることに注意
t_span[1] *= 1 + .3*noise_std
t_eval *= 1 + .3*noise_std

# integrate along baseline vector field
base_path = integrate_model(model_bnn, y0=y0, t_span=t_span, t_eval=t_eval, rtol=1e-12)
base_y = base_path['y'].T

# integrate along HNN vector field
hnn_path = integrate_model(model_hnn, y0=y0, t_span=t_span, t_eval=t_eval, baseline=False, rtol=1e-12)
hnn_y = hnn_path['y'].T

plt.subplot(1,4,1)
plt.title("MSE between coordinates", pad=tpad) ; plt.xlabel('Time step')
plt.plot(t_eval, ((true_y-base_y)**2).mean(-1), 'r-', label='Baseline NN', linewidth=2)
plt.plot(t_eval, ((true_y-hnn_y)**2).mean(-1), 'b-', label='Hamiltonian NN', linewidth=2)
plt.legend(fontsize=7)

plt.subplot(1,4,2)
plt.title("Total HNN-conserved quantity", pad=tpad)
plt.xlabel('Time step')
true_hq = model_hnn(torch.Tensor(true_y)).detach().numpy().squeeze()
base_hq = model_hnn(torch.Tensor(base_y)).detach().numpy().squeeze()
hnn_hq = model_hnn(torch.Tensor(hnn_y)).detach().numpy().squeeze()
plt.plot(t_eval, true_hq, 'k-', label='Ground truth', linewidth=2)
plt.plot(t_eval, base_hq, 'r-', label='Baseline NN', linewidth=2)
plt.plot(t_eval, hnn_hq, 'b-', label='Hamiltonian NN', linewidth=2)
plt.legend(fontsize=7)

plt.subplot(1,4,3)
plt.title("Total energy", pad=tpad)
plt.xlabel('Time step')
true_e = np.stack([hamiltonian_fn(c) for c in true_y]).squeeze()
base_e = np.stack([hamiltonian_fn(c) for c in base_y]).squeeze()
hnn_e = np.stack([hamiltonian_fn(c) for c in hnn_y]).squeeze()
plt.plot(t_eval, true_e, 'k-', label='Ground truth', linewidth=2)
plt.plot(t_eval, base_e, 'r-', label='Baseline NN', linewidth=2)
plt.plot(t_eval, hnn_e, 'b-', label='Hamiltonian NN', linewidth=2)
plt.legend(fontsize=7)
plt.tight_layout() ; plt.show()

ep_nbd = 0.01
for num in range(0,2000):
    if abs(true_e[num]-base_e[num]) > ep_nbd:
        print("BNNによる予測エネルギーがep_nbdを外れる時間",num*(1+.9*noise_std)/2000)
        break
    if num == 1999:
        print("BNNによる予測エネルギーはep_nbdを外れない")

for num in range(0,2000):
    if abs(true_e[num]-hnn_e[num]) > ep_nbd:
        print("HNNによる予測エネルギーがep_nbdを外れる時間",num*(1+.9*noise_std)/2000)
        break
    if num == 1999:
        print("HNNによる予測エネルギーはep_nbdを外れない")
# Out:
# BNNによる予測エネルギーがep_nbdを外れる時間 0.044412499999999994
# HNNによる予測エネルギーはep_nbdを外れない

# %%
from numpy import linalg as LA
fig = plt.figure(figsize=(6.3, 3.1), facecolor='white', dpi=DPI)

#ハミルトニアンとHNNで予測されるハミルトニアンはある定数だけ異なるので補正する
plt.subplot(1,2,1)
plt.title("Hamiltonian p=0", pad=tpad) ; plt.xlabel('q')
p = 0
qs = np.linspace(-3, 3, 2000)
H_true =  np.stack([hamiltonian_fn(np.array([q,p])) for q in qs]).squeeze()
plt.plot(qs, H_true, 'k-', label='Hamiltonian', linewidth=2)
coords = np.stack([np.array([q,p]) for q in qs])
H_pred = model_hnn(torch.Tensor(coords)).detach().numpy().squeeze()
corre = np.full(2000, H_true[1000]-H_pred[1000])
plt.plot(qs, H_pred+corre, 'r-', label='Predicted Hamiltonian', linewidth=2)
plt.legend(fontsize=7)

plt.subplot(1,2,2)
plt.title("Hamiltonian q=0", pad=tpad) ; plt.xlabel('p')
q = 0
ps = np.linspace(-3, 3, 2000)
H_true =  np.stack([hamiltonian_fn(np.array([q,p])) for p in ps]).squeeze()
plt.plot(ps, H_true, 'k-', label='Hamiltonian', linewidth=2)
coords = np.stack([np.array([q,p]) for p in ps])
H_pred = model_hnn(torch.Tensor(coords)).detach().numpy().squeeze()
corre = np.full(2000, H_true[1000] - H_pred[1000])
plt.plot(ps, H_pred + corre, 'r-', label='Predicted Hamiltonian', linewidth=2)
plt.legend(fontsize=7)

plt.tight_layout() ; plt.show()

# %%
import copy
model_bnn_ext, stats_bnn_ext = train(baseline=True, total_steps=9000, data=data_ext)
model_hnn_copy = copy.deepcopy(model_hnn)
model_forced_hnn, stats_forced_hnn = train(baseline=False, total_steps=9000, data=data_ext, ext=True, hnn_model=model_hnn_copy)
model_hnn_ext, stats_hnn_ext = train(baseline=False, data=data_ext, total_steps=9000)
# Out:
# Training baseline model:
# step 0, train_loss 3.4286e-01, test_loss 4.6025e-01
# step 200, train_loss 3.0406e-03, test_loss 3.1042e-03
# step 400, train_loss 3.0237e-03, test_loss 3.1251e-03
# step 600, train_loss 3.0099e-03, test_loss 3.1406e-03
# step 800, train_loss 2.9976e-03, test_loss 3.1574e-03
# step 1000, train_loss 2.9847e-03, test_loss 3.1563e-03
# step 1200, train_loss 2.9697e-03, test_loss 3.1555e-03
# step 1400, train_loss 2.9473e-03, test_loss 3.1409e-03
# step 1600, train_loss 2.9090e-03, test_loss 3.1105e-03
# step 1800, train_loss 2.8356e-03, test_loss 3.0413e-03
# step 2000, train_loss 2.7356e-03, test_loss 2.9493e-03
# step 2200, train_loss 2.6831e-03, test_loss 2.9016e-03
# step 2400, train_loss 2.6740e-03, test_loss 2.8943e-03
# step 2600, train_loss 2.6692e-03, test_loss 2.8965e-03
# step 2800, train_loss 2.6673e-03, test_loss 2.8958e-03
# step 3000, train_loss 2.6665e-03, test_loss 2.8965e-03
# step 3200, train_loss 2.7168e-03, test_loss 2.8917e-03
# step 3400, train_loss 2.6644e-03, test_loss 2.8949e-03
# step 3600, train_loss 2.6641e-03, test_loss 2.8953e-03
# step 3800, train_loss 2.6633e-03, test_loss 2.8941e-03
# step 4000, train_loss 2.8353e-03, test_loss 3.0144e-03
# step 4200, train_loss 2.6656e-03, test_loss 2.8853e-03
# step 4400, train_loss 2.6616e-03, test_loss 2.8913e-03
# step 4600, train_loss 2.6614e-03, test_loss 2.8908e-03
# step 4800, train_loss 2.6608e-03, test_loss 2.8895e-03
# step 5000, train_loss 2.6602e-03, test_loss 2.8881e-03
# step 5200, train_loss 2.6600e-03, test_loss 2.8869e-03
# step 5400, train_loss 2.6593e-03, test_loss 2.8858e-03
# step 5600, train_loss 2.6588e-03, test_loss 2.8838e-03
# step 5800, train_loss 2.6583e-03, test_loss 2.8830e-03
# step 6000, train_loss 2.6575e-03, test_loss 2.8814e-03
# step 6200, train_loss 2.6567e-03, test_loss 2.8797e-03
# step 6400, train_loss 2.6558e-03, test_loss 2.8780e-03
# step 6600, train_loss 2.6547e-03, test_loss 2.8761e-03
# step 6800, train_loss 2.6533e-03, test_loss 2.8740e-03
# step 7000, train_loss 2.6516e-03, test_loss 2.8717e-03
# step 7200, train_loss 2.6493e-03, test_loss 2.8691e-03
# step 7400, train_loss 2.6465e-03, test_loss 2.8661e-03
# step 7600, train_loss 2.6428e-03, test_loss 2.8623e-03
# step 7800, train_loss 2.6379e-03, test_loss 2.8573e-03
# step 8000, train_loss 2.6317e-03, test_loss 2.8537e-03
# step 8200, train_loss 2.6250e-03, test_loss 2.8437e-03
# step 8400, train_loss 2.6189e-03, test_loss 2.8374e-03
# step 8600, train_loss 2.6139e-03, test_loss 2.8329e-03
# step 8800, train_loss 2.6102e-03, test_loss 2.8300e-03
# step 9000, train_loss 2.6076e-03, test_loss 2.8292e-03
# Final train loss 2.6075e-03 +/- 1.4234e-04
# Final test loss 2.8292e-03 +/- 1.6434e-04
# Training  Forced HNN model:
# step 0, train_loss 2.7351e+00, test_loss 4.8867e+00
# step 200, train_loss 1.9543e+00, test_loss 3.4205e+00
# step 400, train_loss 1.3682e+00, test_loss 2.3304e+00
# step 600, train_loss 9.4078e-01, test_loss 1.5471e+00
# step 800, train_loss 6.3869e-01, test_loss 1.0043e+00
# step 1000, train_loss 4.3225e-01, test_loss 6.4249e-01
# step 1200, train_loss 2.9593e-01, test_loss 4.1043e-01
# step 1400, train_loss 2.0856e-01, test_loss 2.6688e-01
# step 1600, train_loss 1.5345e-01, test_loss 1.8059e-01
# step 1800, train_loss 1.1828e-01, test_loss 1.2929e-01
# step 2000, train_loss 9.4739e-02, test_loss 9.8190e-02
# step 2200, train_loss 7.7781e-02, test_loss 7.8226e-02
# step 2400, train_loss 6.4636e-02, test_loss 6.4297e-02
# step 2600, train_loss 5.3918e-02, test_loss 5.3740e-02
# step 2800, train_loss 4.4957e-02, test_loss 4.5227e-02
# step 3000, train_loss 3.7397e-02, test_loss 3.8095e-02
# step 3200, train_loss 3.1003e-02, test_loss 3.1992e-02
# step 3400, train_loss 2.5596e-02, test_loss 2.6716e-02
# step 3600, train_loss 2.1028e-02, test_loss 2.2142e-02
# step 3800, train_loss 1.7181e-02, test_loss 1.8192e-02
# step 4000, train_loss 1.3961e-02, test_loss 1.4813e-02
# step 4200, train_loss 1.1293e-02, test_loss 1.1964e-02
# step 4400, train_loss 9.1125e-03, test_loss 9.6085e-03
# step 4600, train_loss 7.3631e-03, test_loss 7.7059e-03
# step 4800, train_loss 5.9891e-03, test_loss 6.2100e-03
# step 5000, train_loss 4.9358e-03, test_loss 5.0683e-03
# step 5200, train_loss 4.1496e-03, test_loss 4.2243e-03
# step 5400, train_loss 3.5794e-03, test_loss 3.6213e-03
# step 5600, train_loss 3.1783e-03, test_loss 3.2053e-03
# step 5800, train_loss 2.9050e-03, test_loss 2.9286e-03
# step 6000, train_loss 2.7249e-03, test_loss 2.7513e-03
# step 6200, train_loss 2.6105e-03, test_loss 2.6422e-03
# step 6400, train_loss 2.5406e-03, test_loss 2.5779e-03
# step 6600, train_loss 2.4996e-03, test_loss 2.5419e-03
# step 6800, train_loss 2.4767e-03, test_loss 2.5229e-03
# step 7000, train_loss 2.4645e-03, test_loss 2.5138e-03
# step 7200, train_loss 2.4586e-03, test_loss 2.5099e-03
# step 7400, train_loss 2.4558e-03, test_loss 2.5085e-03
# step 7600, train_loss 2.4547e-03, test_loss 2.5082e-03
# step 7800, train_loss 2.4543e-03, test_loss 2.5082e-03
# step 8000, train_loss 2.4542e-03, test_loss 2.5081e-03
# step 8200, train_loss 2.4541e-03, test_loss 2.5081e-03
# step 8400, train_loss 2.4541e-03, test_loss 2.5080e-03
# step 8600, train_loss 2.4542e-03, test_loss 2.5080e-03
# step 8800, train_loss 2.4542e-03, test_loss 2.5079e-03
# step 9000, train_loss 2.4542e-03, test_loss 2.5079e-03
# Final train loss 2.4542e-03 +/- 1.2894e-04
# Final test loss 2.5079e-03 +/- 1.3195e-04
# Training HNN model:
# step 0, train_loss 8.8598e+00, test_loss 1.0561e+01
# step 200, train_loss 6.6762e+00, test_loss 7.8015e+00
# step 400, train_loss 4.9792e+00, test_loss 5.6530e+00
# step 600, train_loss 3.6845e+00, test_loss 4.0590e+00
# step 800, train_loss 2.7156e+00, test_loss 2.9045e+00
# step 1000, train_loss 2.0037e+00, test_loss 2.0865e+00
# step 1200, train_loss 1.4888e+00, test_loss 1.5176e+00
# step 1400, train_loss 1.1199e+00, test_loss 1.1264e+00
# step 1600, train_loss 8.5571e-01, test_loss 8.5732e-01
# step 1800, train_loss 6.6438e-01, test_loss 6.6920e-01
# step 2000, train_loss 5.2277e-01, test_loss 5.3336e-01
# step 2200, train_loss 4.1505e-01, test_loss 4.3102e-01
# step 2400, train_loss 3.3088e-01, test_loss 3.5058e-01
# step 2600, train_loss 2.6365e-01, test_loss 2.8518e-01
# step 2800, train_loss 2.0912e-01, test_loss 2.3077e-01
# step 3000, train_loss 1.6454e-01, test_loss 1.8498e-01
# step 3200, train_loss 1.2802e-01, test_loss 1.4635e-01
# step 3400, train_loss 9.8241e-02, test_loss 1.1397e-01
# step 3600, train_loss 7.4217e-02, test_loss 8.7186e-02
# step 3800, train_loss 5.5156e-02, test_loss 6.5475e-02
# step 4000, train_loss 4.0363e-02, test_loss 4.8315e-02
# step 4200, train_loss 2.9188e-02, test_loss 3.5151e-02
# step 4400, train_loss 2.1010e-02, test_loss 2.5383e-02
# step 4600, train_loss 1.5241e-02, test_loss 1.8397e-02
# step 4800, train_loss 1.1337e-02, test_loss 1.3597e-02
# step 5000, train_loss 8.8173e-03, test_loss 1.0437e-02
# step 5200, train_loss 7.2748e-03, test_loss 8.4507e-03
# step 5400, train_loss 6.3854e-03, test_loss 7.2609e-03
# step 5600, train_loss 5.9057e-03, test_loss 6.5825e-03
# step 5800, train_loss 5.6657e-03, test_loss 6.2137e-03
# step 6000, train_loss 5.5552e-03, test_loss 6.0214e-03
# step 6200, train_loss 5.5088e-03, test_loss 5.9244e-03
# step 6400, train_loss 5.4912e-03, test_loss 5.8765e-03
# step 6600, train_loss 5.4853e-03, test_loss 5.8531e-03
# step 6800, train_loss 5.4835e-03, test_loss 5.8417e-03
# step 7000, train_loss 5.4831e-03, test_loss 5.8362e-03
# step 7200, train_loss 5.4830e-03, test_loss 5.8337e-03
# step 7400, train_loss 5.4830e-03, test_loss 5.8327e-03
# step 7600, train_loss 5.4830e-03, test_loss 5.8322e-03
# step 7800, train_loss 5.4830e-03, test_loss 5.8321e-03
# step 8000, train_loss 5.4830e-03, test_loss 5.8320e-03
# step 8200, train_loss 5.4830e-03, test_loss 5.8320e-03
# step 8400, train_loss 5.4830e-03, test_loss 5.8320e-03
# step 8600, train_loss 5.4830e-03, test_loss 5.8320e-03
# step 8800, train_loss 5.4830e-03, test_loss 5.8320e-03
# step 9000, train_loss 5.4830e-03, test_loss 5.8320e-03
# Final train loss 5.4830e-03 +/- 2.8331e-04
# Final test loss 5.8320e-03 +/- 3.3385e-04

# %%
print(model_forced_hnn.state_dict())
#print(model_hnn_ext.state_dict())
# Out:
# OrderedDict([('ext_model.w', tensor([[ 0.0272],
#         [ 0.0216],
#         [-0.2332],
#         [ 0.0318],
#         [ 0.0111],
#         [ 0.0030],
#         [ 0.0012],
#         [-0.0305],
#         [ 0.2287],
#         [-0.0019]])), ('hnn_model.differentiable_model.w', tensor([[ 7.6493e-04],
#         [ 2.8378e-03],
#         [-1.4792e-03],
#         [ 8.5846e-04],
#         [ 4.9171e-01],
#         [ 4.9532e-01],
#         [-7.6967e-04],
#         [ 3.5146e-04],
#         [-8.4620e-04],
#         [-1.6022e-39]]))])

# %%
integrate_true_ext = integrate(ext=True)
integrate_model_bnn_ext = integrate_model(model_bnn_ext,ext=True)
integrate_model_forced_hnn = integrate_model(model_forced_hnn, baseline=False,ext=True)
integrate_model_hnn_ext = integrate_model(model_hnn_ext, baseline=False,ext=True)

# %%
fig = plt.figure(figsize=(11.3, 10.1), facecolor='white', dpi=DPI)

#plot ground truth ext
fig.add_subplot(2, 2, 1, frameon=True)

for i, l in enumerate(np.split(integrate_true_ext['y'].T, LINE_SEGMENTS)):
    color = (float(i)/LINE_SEGMENTS, 0, 1-float(i)/LINE_SEGMENTS)
    plt.plot(l[:,0],l[:,1], color=color, linewidth=LINE_WIDTH)

plt.xlabel("$q$", fontsize=14)
plt.ylabel("$p$", rotation=0, fontsize=14)
plt.title("Groundtruth", pad=10)

# plot baseline ext
fig.add_subplot(2, 2, 2, frameon=True)

for i, l in enumerate(np.split(integrate_model_bnn_ext['y'].T, LINE_SEGMENTS)):
    color = (float(i)/LINE_SEGMENTS, 0, 1-float(i)/LINE_SEGMENTS)
    plt.plot(l[:,0],l[:,1],color=color, linewidth=LINE_WIDTH)

plt.xlabel("$q$", fontsize=14)
plt.ylabel("$p$", rotation=0, fontsize=14)
plt.title("Baseline NN", pad=10)

# plot Forced HNN
fig.add_subplot(2, 2, 3, frameon=True)

for i, l in enumerate(np.split(integrate_model_forced_hnn['y'].T, LINE_SEGMENTS)):
    color = (float(i)/LINE_SEGMENTS, 0, 1-float(i)/LINE_SEGMENTS)
    plt.plot(l[:,0],l[:,1],color=color, linewidth=LINE_WIDTH)

plt.xlabel("$q$", fontsize=14)
plt.ylabel("$p$", rotation=0, fontsize=14)
plt.title("Forced HNN", pad=10)

# plot HNN ext
fig.add_subplot(2, 2, 4, frameon=True)

for i, l in enumerate(np.split(integrate_model_hnn_ext['y'].T, LINE_SEGMENTS)):
    color = (float(i)/LINE_SEGMENTS, 0, 1-float(i)/LINE_SEGMENTS)
    plt.plot(l[:,0],l[:,1],color=color, linewidth=LINE_WIDTH)

plt.xlabel("$q$", fontsize=14)
plt.ylabel("$p$", rotation=0, fontsize=14)
plt.title("Hamiltonian NN", pad=10)
# Out:
# Text(0.5, 1.0, 'Hamiltonian NN')

# %%
fig = plt.figure(figsize=(12.3, 3.1), facecolor='white', dpi=DPI)
tpad =7
noise_std = 0.05   #ノイズの設定を忘れないこと
t_span = [0,100]
y0 = np.asarray([1, 0])
t_eval=np.linspace(t_span[0], t_span[1], 2000)

# integrate along ground truth vector field
true_path_ext = solve_ivp(fun=dynamics_fn_ext, t_span=t_span, y0=y0, t_eval=t_eval, rtol=1e-12)
true_y_ext = true_path_ext['y'].T

# ノイズの影響を補正するために時間を再スケールする必要があることに注意
t_span[1] *= 1 + .2*noise_std
t_eval *= 1 + .2*noise_std

# integrate along baseline vector field
base_path_ext = integrate_model(model_bnn_ext, y0=y0, t_span=t_span, t_eval=t_eval, rtol=1e-12)
base_y_ext = base_path_ext['y'].T

# integrate along  Forced HNN vector field
forced_hnn_path = integrate_model(model_forced_hnn, y0=y0, t_span=t_span, t_eval=t_eval, baseline=False, rtol=1e-12)
forced_hnn_y = forced_hnn_path['y'].T

# integrate along HNN vector field
hnn_ext_path = integrate_model(model_hnn_ext, y0=y0, t_span=t_span, t_eval=t_eval, baseline=False, rtol=1e-12)
hnn_ext_y = hnn_ext_path['y'].T

plt.subplot(1,3,1)
plt.title("MSE between coordinates", pad=tpad) ; plt.xlabel('Time step')
plt.plot(t_eval, ((true_y_ext-base_y_ext)**2).mean(-1), 'r-', label='Baseline NN', linewidth=2)
plt.plot(t_eval, ((true_y_ext-forced_hnn_y)**2).mean(-1), 'b-', label='Forced HNN', linewidth=2)
plt.plot(t_eval, ((true_y_ext-hnn_ext_y)**2).mean(-1), 'y-', label='Hamiltonian NN', linewidth=2)
plt.legend(fontsize=7)

plt.subplot(1,3,2)
plt.title("Total HNN-conserved quantity", pad=tpad)
plt.xlabel('Time step')
true_hq_ext = model_hnn(torch.Tensor(true_y_ext)).detach().numpy().squeeze()
base_hq_ext = model_hnn(torch.Tensor(base_y_ext)).detach().numpy().squeeze()
forced_hnn_hq = model_hnn(torch.Tensor(forced_hnn_y)).detach().numpy().squeeze()
hnn_ext_hq = model_hnn(torch.Tensor(hnn_ext_y)).detach().numpy().squeeze()
plt.plot(t_eval, true_hq_ext, 'k-', label='Ground truth', linewidth=2)
plt.plot(t_eval, base_hq_ext, 'r-', label='Baseline NN', linewidth=2)
plt.plot(t_eval, forced_hnn_hq, 'b-', label='Forced HNN', linewidth=2)
plt.plot(t_eval, hnn_ext_hq, 'y-', label='Hamiltonian NN', linewidth=2)
plt.legend(fontsize=7)

plt.subplot(1,3,3)
plt.title("Total energy", pad=tpad)
plt.xlabel('Time step')
true_e_ext = np.stack([hamiltonian_fn(c) for c in true_y_ext])
base_e_ext = np.stack([hamiltonian_fn(c) for c in base_y_ext])
forced_hnn_e = np.stack([hamiltonian_fn(c) for c in forced_hnn_y])
hnn_ext_e = np.stack([hamiltonian_fn(c) for c in hnn_ext_y])
plt.plot(t_eval, true_e_ext, 'k-', label='Ground truth', linewidth=2)
plt.plot(t_eval, base_e_ext, 'r-', label='Baseline NN', linewidth=2)
plt.plot(t_eval, forced_hnn_e, 'b-', label='Forced HNN', linewidth=2)
plt.plot(t_eval, hnn_ext_e, 'y-', label='Hamiltonian NN', linewidth=2)
plt.legend(fontsize=7)

plt.tight_layout() ; plt.show()

ep_nbd = 0.01
for num in range(0,2000):
    if abs(true_e_ext[num]-base_e_ext[num]) > ep_nbd:
        print("BNNによる予測エネルギーがep_nbdを外れる時間",num*(1+.9*noise_std)/2000)
        break
    if num == 1999:
        print("BNNによる予測エネルギーはep_nbdを外れない")

for num in range(0,2000):
    if abs(true_e_ext[num]-forced_hnn_e[num]) > ep_nbd:
        print("Forced HNNによる予測エネルギーがep_nbdを外れる時間",num*(1+.9*noise_std)/2000)
        break
    if num == 1999:
        print(" Forced HNNによる予測エネルギーはep_nbdを外れない")

for num in range(0,2000):
    if abs(true_e_ext[num]-hnn_ext_e[num]) > ep_nbd:
        print("HNNによる予測エネルギーがep_nbdを外れる時間",num*(1+.9*noise_std)/2000)
        break
    if num == 1999:
        print(" HNNによる予測エネルギーはep_nbdを外れない")
# Out:
# BNNによる予測エネルギーがep_nbdを外れる時間 0.016197499999999997
# Forced HNNによる予測エネルギーがep_nbdを外れる時間 0.021945
# HNNによる予測エネルギーがep_nbdを外れる時間 0.0015674999999999999

# %%
fig = plt.figure(figsize=(2, 2), facecolor='white', dpi=DPI)

plt.subplot(1,1,1)
plt.title("External force q=0", pad=tpad) ; plt.xlabel('p')
q = 0
ps = np.linspace(-3, 3, 2000)
ext_true =  np.stack([ext_f(np.array([q,p])) for p in ps]).squeeze()
plt.plot(ps, ext_true, 'k-', label='External force', linewidth=2)
coords = np.stack([np.array([q,p]) for p in ps])
ext_pred = model_forced_hnn(torch.Tensor(coords)).detach().numpy().squeeze()
plt.plot(ps, ext_pred, 'b-', label='Predicted External force', linewidth=2)
coord = np.stack([np.array([p]) for p in ps])

plt.tight_layout() ; plt.show()

# %%
data = get_dataset(noise_std=0.0)
data_ext = get_dataset(ext=True, noise_std=0.0)

# %%
model_bnn, stats_bnn = train(baseline=True, data=data, total_steps=2000)
model_hnn, stats_hnn = train(baseline=False, data=data, total_steps=9000)
# Out:
# Training baseline model:
# step 0, train_loss 2.5021e-01, test_loss 3.7561e-01
# step 200, train_loss 2.5762e-06, test_loss 3.7249e-06
# step 400, train_loss 2.3094e-06, test_loss 3.1483e-06
# step 600, train_loss 2.1774e-06, test_loss 2.7452e-06
# step 800, train_loss 2.2304e-04, test_loss 2.1031e-05
# step 1000, train_loss 1.9271e-06, test_loss 2.2468e-06
# step 1200, train_loss 2.0784e-06, test_loss 2.0772e-06
# step 1400, train_loss 1.8123e-06, test_loss 1.9715e-06
# step 1600, train_loss 1.9361e-06, test_loss 3.4566e-06
# step 1800, train_loss 1.7250e-06, test_loss 1.8299e-06
# step 2000, train_loss 1.7281e-05, test_loss 2.9772e-05
# Final train loss 2.9547e-05 +/- 1.0104e-06
# Final test loss 2.9772e-05 +/- 9.6018e-07
# Training HNN model:
# step 0, train_loss 7.1002e+00, test_loss 8.1239e+00
# step 200, train_loss 5.4371e+00, test_loss 5.9250e+00
# step 400, train_loss 4.1602e+00, test_loss 4.3540e+00
# step 600, train_loss 3.1726e+00, test_loss 3.2306e+00
# step 800, train_loss 2.4122e+00, test_loss 2.4098e+00
# step 1000, train_loss 1.8341e+00, test_loss 1.8049e+00
# step 1200, train_loss 1.3998e+00, test_loss 1.3617e+00
# step 1400, train_loss 1.0758e+00, test_loss 1.0395e+00
# step 1600, train_loss 8.3477e-01, test_loss 8.0584e-01
# step 1800, train_loss 6.5458e-01, test_loss 6.3526e-01
# step 2000, train_loss 5.1842e-01, test_loss 5.0877e-01
# step 2200, train_loss 4.1382e-01, test_loss 4.1266e-01
# step 2400, train_loss 3.3188e-01, test_loss 3.3736e-01
# step 2600, train_loss 2.6638e-01, test_loss 2.7643e-01
# step 2800, train_loss 2.1306e-01, test_loss 2.2569e-01
# step 3000, train_loss 1.6909e-01, test_loss 1.8256e-01
# step 3200, train_loss 1.3258e-01, test_loss 1.4555e-01
# step 3400, train_loss 1.0228e-01, test_loss 1.1386e-01
# step 3600, train_loss 7.7350e-02, test_loss 8.7049e-02
# step 3800, train_loss 5.7131e-02, test_loss 6.4819e-02
# step 4000, train_loss 4.1068e-02, test_loss 4.6858e-02
# step 4200, train_loss 2.8626e-02, test_loss 3.2783e-02
# step 4400, train_loss 1.9274e-02, test_loss 2.2120e-02
# step 4600, train_loss 1.2482e-02, test_loss 1.4341e-02
# step 4800, train_loss 7.7393e-03, test_loss 8.8956e-03
# step 5000, train_loss 4.5701e-03, test_loss 5.2530e-03
# step 5200, train_loss 2.5554e-03, test_loss 2.9368e-03
# step 5400, train_loss 1.3445e-03, test_loss 1.5449e-03
# step 5600, train_loss 6.6099e-04, test_loss 7.5940e-04
# step 5800, train_loss 3.0129e-04, test_loss 3.4619e-04
# step 6000, train_loss 1.2627e-04, test_loss 1.4517e-04
# step 6200, train_loss 4.8208e-05, test_loss 5.5497e-05
# step 6400, train_loss 1.6600e-05, test_loss 1.9168e-05
# step 6600, train_loss 5.1016e-06, test_loss 5.9289e-06
# step 6800, train_loss 1.3857e-06, test_loss 1.6330e-06
# step 7000, train_loss 3.3115e-07, test_loss 4.0257e-07
# step 7200, train_loss 7.1191e-08, test_loss 9.2711e-08
# step 7400, train_loss 1.5860e-08, test_loss 2.3402e-08
# step 7600, train_loss 5.6064e-09, test_loss 9.0354e-09
# step 7800, train_loss 3.8524e-09, test_loss 5.9901e-09
# step 8000, train_loss 3.5682e-09, test_loss 5.3117e-09
# step 8200, train_loss 3.5112e-09, test_loss 5.1393e-09
# step 8400, train_loss 3.4956e-09, test_loss 5.0901e-09
# step 8600, train_loss 3.4879e-09, test_loss 5.0739e-09
# step 8800, train_loss 3.4864e-09, test_loss 5.0696e-09
# step 9000, train_loss 3.4818e-09, test_loss 5.0626e-09
# Final train loss 3.4818e-09 +/- 1.7882e-10
# Final test loss 5.0626e-09 +/- 2.9695e-10

# %%
print(model_hnn.state_dict())
# Out:
# OrderedDict([('differentiable_model.w', tensor([[ 2.2387e-06],
#         [-3.4855e-05],
#         [-2.5667e-05],
#         [-8.3986e-06],
#         [ 4.9994e-01],
#         [ 4.9993e-01],
#         [-1.9082e-06],
#         [ 2.9096e-06],
#         [ 1.3549e-05],
#         [-1.6022e-39]]))])

# %%
integrate_true = integrate()
integrate_model_bnn = integrate_model(model_bnn)
integrate_model_hnn = integrate_model(model_hnn, baseline=False)

# %%
fig = plt.figure(figsize=(12.3, 3.1), facecolor='white', dpi=DPI)

#plot ground truth
fig.add_subplot(1, 3, 1, frameon=True)

for i, l in enumerate(np.split(integrate_true['y'].T, LINE_SEGMENTS)):
    color = (float(i)/LINE_SEGMENTS, 0, 1-float(i)/LINE_SEGMENTS)
    plt.plot(l[:,0],l[:,1], color=color, linewidth=LINE_WIDTH)

plt.xlabel("$q$", fontsize=14)
plt.ylabel("$p$", rotation=0, fontsize=14)
plt.title("Groundtruth", pad=10)

# plot baseline
fig.add_subplot(1, 3, 2, frameon=True)

for i, l in enumerate(np.split(integrate_model_bnn['y'].T, LINE_SEGMENTS)):
    color = (float(i)/LINE_SEGMENTS, 0, 1-float(i)/LINE_SEGMENTS)
    plt.plot(l[:,0],l[:,1],color=color, linewidth=LINE_WIDTH)

plt.xlabel("$q$", fontsize=14)
plt.ylabel("$p$", rotation=0, fontsize=14)
plt.title("Baseline NN", pad=10)

# plot HNN
fig.add_subplot(1, 3, 3, frameon=True)

for i, l in enumerate(np.split(integrate_model_hnn['y'].T, LINE_SEGMENTS)):
    color = (float(i)/LINE_SEGMENTS, 0, 1-float(i)/LINE_SEGMENTS)
    plt.plot(l[:,0],l[:,1],color=color, linewidth=LINE_WIDTH)

plt.xlabel("$q$", fontsize=14)
plt.ylabel("$p$", rotation=0, fontsize=14)
plt.title("HNN", pad=10)
# Out:
# Text(0.5, 1.0, 'HNN')

# %%
fig = plt.figure(figsize=(12.3, 3.1), facecolor='white', dpi=DPI)
tpad =7
noise_std = 0.0   #ノイズの設定を忘れないこと
t_span = [0,100]
y0 = np.asarray([1, 0])
t_eval=np.linspace(t_span[0], t_span[1], 2000)

# integrate along ground truth vector field
true_path = solve_ivp(fun=dynamics_fn, t_span=t_span, y0=y0, t_eval=t_eval, rtol=1e-12)
true_y = true_path['y'].T

# ノイズの影響を補正するために時間を再スケールする必要があることに注意
t_span[1] *= 1 + .3*noise_std
t_eval *= 1 + .3*noise_std

# integrate along baseline vector field
base_path = integrate_model(model_bnn, y0=y0, t_span=t_span, t_eval=t_eval, rtol=1e-12)
base_y = base_path['y'].T

# integrate along HNN vector field
hnn_path = integrate_model(model_hnn, y0=y0, t_span=t_span, t_eval=t_eval, baseline=False, rtol=1e-12)
hnn_y = hnn_path['y'].T

plt.subplot(1,3,1)
plt.title("MSE between coordinates", pad=tpad) ; plt.xlabel('Time step')
plt.plot(t_eval, ((true_y-base_y)**2).mean(-1), 'r-', label='Baseline NN', linewidth=2)
plt.plot(t_eval, ((true_y-hnn_y)**2).mean(-1), 'b-', label='Hamiltonian NN', linewidth=2)
plt.legend(fontsize=7)

plt.subplot(1,3,2)
plt.title("Total HNN-conserved quantity", pad=tpad)
plt.xlabel('Time step')
true_hq = model_hnn(torch.Tensor(true_y)).detach().numpy().squeeze()
base_hq = model_hnn(torch.Tensor(base_y)).detach().numpy().squeeze()
hnn_hq = model_hnn(torch.Tensor(hnn_y)).detach().numpy().squeeze()
plt.plot(t_eval, true_hq, 'k-', label='Ground truth', linewidth=2)
plt.plot(t_eval, base_hq, 'r-', label='Baseline NN', linewidth=2)
plt.plot(t_eval, hnn_hq, 'b-', label='Hamiltonian NN', linewidth=2)
plt.legend(fontsize=7)

plt.subplot(1,3,3)
plt.title("Total energy", pad=tpad)
plt.xlabel('Time step')
true_e = np.stack([hamiltonian_fn(c) for c in true_y]).squeeze()
base_e = np.stack([hamiltonian_fn(c) for c in base_y]).squeeze()
hnn_e = np.stack([hamiltonian_fn(c) for c in hnn_y]).squeeze()
plt.plot(t_eval, true_e, 'k-', label='Ground truth', linewidth=2)
plt.plot(t_eval, base_e, 'r-', label='Baseline NN', linewidth=2)
plt.plot(t_eval, hnn_e, 'b-', label='Hamiltonian NN', linewidth=2)
plt.legend(fontsize=7)
plt.tight_layout() ; plt.show()

ep_nbd = 0.01
for num in range(0,2000):
    if abs(true_e[num]-base_e[num]) > ep_nbd:
        print("BNNによる予測エネルギーがep_nbdを外れる時間",num*(1+.9*noise_std)/2000)
        break
    if num == 1999:
        print("BNNによる予測エネルギーはep_nbdを外れない")

for num in range(0,2000):
    if abs(true_e[num]-hnn_e[num]) > ep_nbd:
        print("HNNによる予測エネルギーがep_nbdを外れる時間",num*(1+.9*noise_std)/2000)
        break
    if num == 1999:
        print("HNNによる予測エネルギーはep_nbdを外れない")
# Out:
# BNNによる予測エネルギーがep_nbdを外れる時間 0.021
# HNNによる予測エネルギーはep_nbdを外れない

# %%
from numpy import linalg as LA
fig = plt.figure(figsize=(6.3, 3.1), facecolor='white', dpi=DPI)

#ハミルトニアンとHNNで予測されるハミルトニアンはある定数だけ異なるので補正する
plt.subplot(1,2,1)
plt.title("Hamiltonian p=0", pad=tpad) ; plt.xlabel('q')
p = 0
qs = np.linspace(-3, 3, 2000)
H_true =  np.stack([hamiltonian_fn(np.array([q,p])) for q in qs]).squeeze()
plt.plot(qs, H_true, 'k-', label='Hamiltonian', linewidth=2)
coords = np.stack([np.array([q,p]) for q in qs])
H_pred = model_hnn(torch.Tensor(coords)).detach().numpy().squeeze()
corre = np.full(2000, H_true[1000]-H_pred[1000])
plt.plot(qs, H_pred+corre, 'r-', label='Predicted Hamiltonian', linewidth=2)
plt.legend(fontsize=7)

plt.subplot(1,2,2)
plt.title("Hamiltonian q=0", pad=tpad) ; plt.xlabel('p')
q = 0
ps = np.linspace(-3, 3, 2000)
H_true =  np.stack([hamiltonian_fn(np.array([q,p])) for p in ps]).squeeze()
plt.plot(ps, H_true, 'k-', label='Hamiltonian', linewidth=2)
coords = np.stack([np.array([q,p]) for p in ps])
H_pred = model_hnn(torch.Tensor(coords)).detach().numpy().squeeze()
corre = np.full(2000, H_true[1000] - H_pred[1000])
plt.plot(ps, H_pred + corre, 'r-', label='Predicted Hamiltonian', linewidth=2)
plt.legend(fontsize=7)

plt.tight_layout() ; plt.show()

# %%
import copy
model_bnn_ext, stats_bnn_ext = train(baseline=True, total_steps=9000, data=data_ext)
model_hnn_copy = copy.deepcopy(model_hnn)
model_forced_hnn, stats_forced_hnn = train(baseline=False, total_steps=9000, data=data_ext, ext=True, hnn_model=model_hnn_copy)
model_hnn_ext, stats_hnn_ext = train(baseline=False, data=data_ext, total_steps=9000)
# Out:
# Training baseline model:
# step 0, train_loss 3.4278e-01, test_loss 4.6030e-01
# step 200, train_loss 6.1384e-04, test_loss 6.6680e-04
# step 400, train_loss 6.0012e-04, test_loss 6.8295e-04
# step 600, train_loss 5.8879e-04, test_loss 6.9575e-04
# step 800, train_loss 5.8283e-04, test_loss 9.3454e-04
# step 1000, train_loss 5.6898e-04, test_loss 7.0575e-04
# step 1200, train_loss 5.6026e-04, test_loss 7.0751e-04
# step 1400, train_loss 5.4703e-04, test_loss 6.9939e-04
# step 1600, train_loss 5.4428e-04, test_loss 7.5285e-04
# step 1800, train_loss 4.9909e-04, test_loss 6.5307e-04
# step 2000, train_loss 8.2412e-04, test_loss 6.3788e-04
# step 2200, train_loss 3.6408e-04, test_loss 5.0544e-04
# step 2400, train_loss 3.1585e-04, test_loss 4.5009e-04
# step 2600, train_loss 3.0510e-04, test_loss 4.4444e-04
# step 2800, train_loss 3.0230e-04, test_loss 4.4196e-04
# step 3000, train_loss 3.0173e-04, test_loss 4.4381e-04
# step 3200, train_loss 3.0097e-04, test_loss 4.3985e-04
# step 3400, train_loss 3.0048e-04, test_loss 4.4028e-04
# step 3600, train_loss 3.0078e-04, test_loss 4.4070e-04
# step 3800, train_loss 3.0039e-04, test_loss 4.3900e-04
# step 4000, train_loss 3.0012e-04, test_loss 4.3708e-04
# step 4200, train_loss 3.0049e-04, test_loss 4.3696e-04
# step 4400, train_loss 3.0017e-04, test_loss 4.3503e-04
# step 4600, train_loss 1.6453e-03, test_loss 2.1307e-03
# step 4800, train_loss 3.0061e-04, test_loss 4.3302e-04
# step 5000, train_loss 3.0038e-04, test_loss 4.3124e-04
# step 5200, train_loss 3.0724e-04, test_loss 4.2028e-04
# step 5400, train_loss 3.0030e-04, test_loss 4.2799e-04
# step 5600, train_loss 3.0173e-04, test_loss 4.3251e-04
# step 5800, train_loss 3.0062e-04, test_loss 4.2525e-04
# step 6000, train_loss 3.0058e-04, test_loss 4.2356e-04
# step 6200, train_loss 3.0060e-04, test_loss 4.2181e-04
# step 6400, train_loss 3.0077e-04, test_loss 4.2071e-04
# step 6600, train_loss 3.0077e-04, test_loss 4.1928e-04
# step 6800, train_loss 3.0078e-04, test_loss 4.1801e-04
# step 7000, train_loss 3.0076e-04, test_loss 4.1692e-04
# step 7200, train_loss 3.0069e-04, test_loss 4.1608e-04
# step 7400, train_loss 3.0053e-04, test_loss 4.1554e-04
# step 7600, train_loss 3.0024e-04, test_loss 4.1537e-04
# step 7800, train_loss 2.9980e-04, test_loss 4.1561e-04
# step 8000, train_loss 2.9920e-04, test_loss 4.1624e-04
# step 8200, train_loss 2.9850e-04, test_loss 4.1722e-04
# step 8400, train_loss 2.9771e-04, test_loss 4.1802e-04
# step 8600, train_loss 3.1363e-04, test_loss 4.1728e-04
# step 8800, train_loss 2.9575e-04, test_loss 4.2035e-04
# step 9000, train_loss 2.9474e-04, test_loss 4.2103e-04
# Final train loss 2.9473e-04 +/- 2.7940e-05
# Final test loss 4.2103e-04 +/- 6.3877e-05
# Training  Forced HNN model:
# step 0, train_loss 2.6868e+00, test_loss 4.7935e+00
# step 200, train_loss 1.9163e+00, test_loss 3.3544e+00
# step 400, train_loss 1.3381e+00, test_loss 2.2826e+00
# step 600, train_loss 9.1678e-01, test_loss 1.5109e+00
# step 800, train_loss 6.1963e-01, test_loss 9.7566e-01
# step 1000, train_loss 4.1723e-01, test_loss 6.1931e-01
# step 1200, train_loss 2.8414e-01, test_loss 3.9173e-01
# step 1400, train_loss 1.9927e-01, test_loss 2.5201e-01
# step 1600, train_loss 1.4601e-01, test_loss 1.6885e-01
# step 1800, train_loss 1.1220e-01, test_loss 1.1996e-01
# step 2000, train_loss 8.9651e-02, test_loss 9.0649e-02
# step 2200, train_loss 7.3428e-02, test_loss 7.1979e-02
# step 2400, train_loss 6.0837e-02, test_loss 5.8991e-02
# step 2600, train_loss 5.0545e-02, test_loss 4.9135e-02
# step 2800, train_loss 4.1918e-02, test_loss 4.1164e-02
# step 3000, train_loss 3.4621e-02, test_loss 3.4469e-02
# step 3200, train_loss 2.8438e-02, test_loss 2.8731e-02
# step 3400, train_loss 2.3199e-02, test_loss 2.3767e-02
# step 3600, train_loss 1.8763e-02, test_loss 1.9458e-02
# step 3800, train_loss 1.5016e-02, test_loss 1.5728e-02
# step 4000, train_loss 1.1866e-02, test_loss 1.2523e-02
# step 4200, train_loss 9.2382e-03, test_loss 9.8031e-03
# step 4400, train_loss 7.0730e-03, test_loss 7.5313e-03
# step 4600, train_loss 5.3161e-03, test_loss 5.6712e-03
# step 4800, train_loss 3.9167e-03, test_loss 4.1819e-03
# step 5000, train_loss 2.8249e-03, test_loss 3.0180e-03
# step 5200, train_loss 1.9922e-03, test_loss 2.1308e-03
# step 5400, train_loss 1.3719e-03, test_loss 1.4713e-03
# step 5600, train_loss 9.2126e-04, test_loss 9.9296e-04
# step 5800, train_loss 6.0206e-04, test_loss 6.5409e-04
# step 6000, train_loss 3.8193e-04, test_loss 4.1956e-04
# step 6200, train_loss 2.3439e-04, test_loss 2.6106e-04
# step 6400, train_loss 1.3853e-04, test_loss 1.5674e-04
# step 6600, train_loss 7.8409e-05, test_loss 9.0187e-05
# step 6800, train_loss 4.2209e-05, test_loss 4.9336e-05
# step 7000, train_loss 2.1433e-05, test_loss 2.5428e-05
# step 7200, train_loss 1.0162e-05, test_loss 1.2220e-05
# step 7400, train_loss 4.4403e-06, test_loss 5.4100e-06
# step 7600, train_loss 1.7563e-06, test_loss 2.1734e-06
# step 7800, train_loss 6.1289e-07, test_loss 7.7783e-07
# step 8000, train_loss 1.8332e-07, test_loss 2.4579e-07
# step 8200, train_loss 5.0063e-08, test_loss 7.6010e-08
# step 8400, train_loss 2.2989e-08, test_loss 3.7951e-08
# step 8600, train_loss 2.5877e-08, test_loss 3.8358e-08
# step 8800, train_loss 3.3015e-08, test_loss 4.5291e-08
# step 9000, train_loss 3.8068e-08, test_loss 5.0508e-08
# Final train loss 3.8086e-08 +/- 2.8622e-09
# Final test loss 5.0508e-08 +/- 5.5499e-09
# Training HNN model:
# step 0, train_loss 8.7295e+00, test_loss 1.0474e+01
# step 200, train_loss 6.5830e+00, test_loss 7.7104e+00
# step 400, train_loss 4.9128e+00, test_loss 5.5859e+00
# step 600, train_loss 3.6376e+00, test_loss 4.0107e+00
# step 800, train_loss 2.6825e+00, test_loss 2.8699e+00
# step 1000, train_loss 1.9802e+00, test_loss 2.0617e+00
# step 1200, train_loss 1.4716e+00, test_loss 1.4995e+00
# step 1400, train_loss 1.1070e+00, test_loss 1.1130e+00
# step 1600, train_loss 8.4573e-01, test_loss 8.4725e-01
# step 1800, train_loss 6.5649e-01, test_loss 6.6161e-01
# step 2000, train_loss 5.1646e-01, test_loss 5.2767e-01
# step 2200, train_loss 4.0999e-01, test_loss 4.2681e-01
# step 2400, train_loss 3.2679e-01, test_loss 3.4746e-01
# step 2600, train_loss 2.6029e-01, test_loss 2.8279e-01
# step 2800, train_loss 2.0629e-01, test_loss 2.2883e-01
# step 3000, train_loss 1.6205e-01, test_loss 1.8325e-01
# step 3200, train_loss 1.2573e-01, test_loss 1.4468e-01
# step 3400, train_loss 9.6044e-02, test_loss 1.1226e-01
# step 3600, train_loss 7.2053e-02, test_loss 8.5409e-02
# step 3800, train_loss 5.2989e-02, test_loss 6.3611e-02
# step 4000, train_loss 3.8175e-02, test_loss 4.6368e-02
# step 4200, train_loss 2.6972e-02, test_loss 3.3127e-02
# step 4400, train_loss 1.8767e-02, test_loss 2.3289e-02
# step 4600, train_loss 1.2972e-02, test_loss 1.6241e-02
# step 4800, train_loss 9.0476e-03, test_loss 1.1385e-02
# step 5000, train_loss 6.5111e-03, test_loss 8.1782e-03
# step 5200, train_loss 4.9564e-03, test_loss 6.1536e-03
# step 5400, train_loss 4.0585e-03, test_loss 4.9339e-03
# step 5600, train_loss 3.5733e-03, test_loss 4.2331e-03
# step 5800, train_loss 3.3299e-03, test_loss 3.8483e-03
# step 6000, train_loss 3.2176e-03, test_loss 3.6453e-03
# step 6200, train_loss 3.1703e-03, test_loss 3.5414e-03
# step 6400, train_loss 3.1524e-03, test_loss 3.4893e-03
# step 6600, train_loss 3.1463e-03, test_loss 3.4634e-03
# step 6800, train_loss 3.1445e-03, test_loss 3.4506e-03
# step 7000, train_loss 3.1440e-03, test_loss 3.4445e-03
# step 7200, train_loss 3.1439e-03, test_loss 3.4416e-03
# step 7400, train_loss 3.1439e-03, test_loss 3.4404e-03
# step 7600, train_loss 3.1439e-03, test_loss 3.4399e-03
# step 7800, train_loss 3.1439e-03, test_loss 3.4397e-03
# step 8000, train_loss 3.1439e-03, test_loss 3.4397e-03
# step 8200, train_loss 3.1439e-03, test_loss 3.4397e-03
# step 8400, train_loss 3.1439e-03, test_loss 3.4397e-03
# step 8600, train_loss 3.1439e-03, test_loss 3.4397e-03
# step 8800, train_loss 3.1439e-03, test_loss 3.4397e-03
# step 9000, train_loss 3.1439e-03, test_loss 3.4397e-03
# Final train loss 3.1439e-03 +/- 1.6294e-04
# Final test loss 3.4397e-03 +/- 2.0316e-04

# %%
print(model_forced_hnn.state_dict())
#print(model_hnn_ext.state_dict())
# Out:
# OrderedDict([('ext_model.w', tensor([[ 2.0677e-05],
#         [ 9.7032e-04],
#         [-2.4806e-01],
#         [-3.2379e-04],
#         [ 8.3390e-05],
#         [ 4.2518e-05],
#         [ 2.5240e-04],
#         [-1.3436e-04],
#         [ 2.4892e-01],
#         [-2.6809e-05]])), ('hnn_model.differentiable_model.w', tensor([[ 2.2387e-06],
#         [-3.4855e-05],
#         [-2.5667e-05],
#         [-8.3986e-06],
#         [ 4.9994e-01],
#         [ 4.9993e-01],
#         [-1.9082e-06],
#         [ 2.9096e-06],
#         [ 1.3549e-05],
#         [-1.6022e-39]]))])

# %%
integrate_true_ext = integrate(ext=True)
integrate_model_bnn_ext = integrate_model(model_bnn_ext,ext=True)
integrate_model_forced_hnn = integrate_model(model_forced_hnn, baseline=False,ext=True)
integrate_model_hnn_ext = integrate_model(model_hnn_ext, baseline=False,ext=True)

# %%
fig = plt.figure(figsize=(11.3, 10.1), facecolor='white', dpi=DPI)

#plot ground truth ext
fig.add_subplot(2, 2, 1, frameon=True)

for i, l in enumerate(np.split(integrate_true_ext['y'].T, LINE_SEGMENTS)):
    color = (float(i)/LINE_SEGMENTS, 0, 1-float(i)/LINE_SEGMENTS)
    plt.plot(l[:,0],l[:,1], color=color, linewidth=LINE_WIDTH)

plt.xlabel("$q$", fontsize=14)
plt.ylabel("$p$", rotation=0, fontsize=14)
plt.title("Groundtruth", pad=10)

# plot baseline ext
fig.add_subplot(2, 2, 2, frameon=True)

for i, l in enumerate(np.split(integrate_model_bnn_ext['y'].T, LINE_SEGMENTS)):
    color = (float(i)/LINE_SEGMENTS, 0, 1-float(i)/LINE_SEGMENTS)
    plt.plot(l[:,0],l[:,1],color=color, linewidth=LINE_WIDTH)

plt.xlabel("$q$", fontsize=14)
plt.ylabel("$p$", rotation=0, fontsize=14)
plt.title("Baseline NN", pad=10)

# plot Forced HNN
fig.add_subplot(2, 2, 3, frameon=True)

for i, l in enumerate(np.split(integrate_model_forced_hnn['y'].T, LINE_SEGMENTS)):
    color = (float(i)/LINE_SEGMENTS, 0, 1-float(i)/LINE_SEGMENTS)
    plt.plot(l[:,0],l[:,1],color=color, linewidth=LINE_WIDTH)

plt.xlabel("$q$", fontsize=14)
plt.ylabel("$p$", rotation=0, fontsize=14)
plt.title("Forced HNN", pad=10)

# plot HNN ext
fig.add_subplot(2, 2, 4, frameon=True)

for i, l in enumerate(np.split(integrate_model_hnn_ext['y'].T, LINE_SEGMENTS)):
    color = (float(i)/LINE_SEGMENTS, 0, 1-float(i)/LINE_SEGMENTS)
    plt.plot(l[:,0],l[:,1],color=color, linewidth=LINE_WIDTH)

plt.xlabel("$q$", fontsize=14)
plt.ylabel("$p$", rotation=0, fontsize=14)
plt.title("Hamiltonian NN", pad=10)
# Out:
# Text(0.5, 1.0, 'Hamiltonian NN')

# %%
fig = plt.figure(figsize=(12.3, 3.1), facecolor='white', dpi=DPI)
tpad =7
noise_std = 0.0   #ノイズの設定を忘れないこと
t_span = [0,100]
y0 = np.asarray([1, 0])
t_eval=np.linspace(t_span[0], t_span[1], 2000)

# integrate along ground truth vector field
true_path_ext = solve_ivp(fun=dynamics_fn_ext, t_span=t_span, y0=y0, t_eval=t_eval, rtol=1e-12)
true_y_ext = true_path_ext['y'].T

# ノイズの影響を補正するために時間を再スケールする必要があることに注意
t_span[1] *= 1 + .7*noise_std
t_eval *= 1 + .7*noise_std

# integrate along baseline vector field
base_path_ext = integrate_model(model_bnn_ext, y0=y0, t_span=t_span, t_eval=t_eval, rtol=1e-12)
base_y_ext = base_path_ext['y'].T

# integrate along  Forced HNN vector field
forced_hnn_path = integrate_model(model_forced_hnn, y0=y0, t_span=t_span, t_eval=t_eval, baseline=False, rtol=1e-12)
forced_hnn_y = forced_hnn_path['y'].T

# integrate along HNN vector field
hnn_ext_path = integrate_model(model_hnn_ext, y0=y0, t_span=t_span, t_eval=t_eval, baseline=False, rtol=1e-12)
hnn_ext_y = hnn_ext_path['y'].T

plt.subplot(1,3,1)
plt.title("MSE between coordinates", pad=tpad) ; plt.xlabel('Time step')
plt.plot(t_eval, ((true_y_ext-base_y_ext)**2).mean(-1), 'r-', label='Baseline NN', linewidth=2)
plt.plot(t_eval, ((true_y_ext-forced_hnn_y)**2).mean(-1), 'b-', label='Forced HNN', linewidth=2)
plt.plot(t_eval, ((true_y_ext-hnn_ext_y)**2).mean(-1), 'y-', label='Hamiltonian NN', linewidth=2)
plt.legend(fontsize=7)

plt.subplot(1,3,2)
plt.title("Total HNN-conserved quantity", pad=tpad)
plt.xlabel('Time step')
true_hq_ext = model_hnn(torch.Tensor(true_y_ext)).detach().numpy().squeeze()
base_hq_ext = model_hnn(torch.Tensor(base_y_ext)).detach().numpy().squeeze()
forced_hnn_hq = model_hnn(torch.Tensor(forced_hnn_y)).detach().numpy().squeeze()
hnn_ext_hq = model_hnn(torch.Tensor(hnn_ext_y)).detach().numpy().squeeze()
plt.plot(t_eval, true_hq_ext, 'k-', label='Ground truth', linewidth=2)
plt.plot(t_eval, base_hq_ext, 'r-', label='Baseline NN', linewidth=2)
plt.plot(t_eval, forced_hnn_hq, 'b-', label='Forced HNN', linewidth=2)
plt.plot(t_eval, hnn_ext_hq, 'y-', label='Hamiltonian NN', linewidth=2)
plt.legend(fontsize=7)

plt.subplot(1,3,3)
plt.title("Total energy", pad=tpad)
plt.xlabel('Time step')
true_e_ext = np.stack([hamiltonian_fn(c) for c in true_y_ext])
base_e_ext = np.stack([hamiltonian_fn(c) for c in base_y_ext])
forced_hnn_e = np.stack([hamiltonian_fn(c) for c in forced_hnn_y])
hnn_ext_e = np.stack([hamiltonian_fn(c) for c in hnn_ext_y])
plt.plot(t_eval, true_e_ext, 'k-', label='Ground truth', linewidth=2)
plt.plot(t_eval, base_e_ext, 'r-', label='Baseline NN', linewidth=2)
plt.plot(t_eval, forced_hnn_e, 'b-', label='Forced HNN', linewidth=2)
plt.plot(t_eval, hnn_ext_e, 'y-', label='Hamiltonian NN', linewidth=2)
plt.legend(fontsize=7)

plt.tight_layout() ; plt.show()

ep_nbd = 0.01
for num in range(0,2000):
    if abs(true_e_ext[num]-base_e_ext[num]) > ep_nbd:
        print("BNNによる予測エネルギーがep_nbdを外れる時間",num*(1+.9*noise_std)/2000)
        break
    if num == 1999:
        print("BNNによる予測エネルギーはep_nbdを外れない")

for num in range(0,2000):
    if abs(true_e_ext[num]-forced_hnn_e[num]) > ep_nbd:
        print("Forced HNNによる予測エネルギーがep_nbdを外れる時間",num*(1+.9*noise_std)/2000)
        break
    if num == 1999:
        print(" Forced HNNによる予測エネルギーはep_nbdを外れない")

for num in range(0,2000):
    if abs(true_e_ext[num]-hnn_ext_e[num]) > ep_nbd:
        print("HNNによる予測エネルギーがep_nbdを外れる時間",num*(1+.9*noise_std)/2000)
        break
    if num == 1999:
        print(" HNNによる予測エネルギーはep_nbdを外れない")
# Out:
# BNNによる予測エネルギーがep_nbdを外れる時間 0.014
# Forced HNNによる予測エネルギーがep_nbdを外れる時間 0.0785
# HNNによる予測エネルギーがep_nbdを外れる時間 0.0015

# %%
fig = plt.figure(figsize=(2, 2), facecolor='white', dpi=DPI)

plt.subplot(1,1,1)
plt.title("External force q=0", pad=tpad) ; plt.xlabel('p')
q = 0
ps = np.linspace(-3, 3, 2000)
ext_true =  np.stack([ext_f(np.array([q,p])) for p in ps]).squeeze()
plt.plot(ps, ext_true, 'k-', label='External force', linewidth=2)
coords = np.stack([np.array([q,p]) for p in ps])
ext_pred = model_forced_hnn(torch.Tensor(coords)).detach().numpy().squeeze()
plt.plot(ps, ext_pred, 'b-', label='Predicted External force', linewidth=2)
coord = np.stack([np.array([p]) for p in ps])

plt.tight_layout() ; plt.show()
